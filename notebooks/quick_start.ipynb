# %% [markdown]
# # Customer Segmentation Analysis - Quick Start
#
# This notebook demonstrates the modern customer segmentation analysis capabilities.
#
# ## Overview
# - Multiple clustering algorithms
# - Business insights and recommendations
# - Interactive visualizations
# - Comprehensive evaluation
